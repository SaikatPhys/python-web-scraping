# %% [markdown]
# In this ipython notebook we scrape tweets by employing various searching modes depending on the use-case at hand, e.g., scrape tweets from a particular user, scrape followers' information etc.
#
# We use the OSINT scrapper `Twint` in a Pythonic way. Check out [Twint's Github page](https://github.com/twintproject/twint) for more details.
#
# For configuration options of Twint see [here](https://github.com/twintproject/twint/wiki/Configuration).

# %% [markdown]
# ### 1 - Installs and imports

# %%
# !pip3 install --upgrade -e git+https://github.com/twintproject/twint.git@origin/master#egg=twint
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining twint from git+https://github.com/twintproject/twint.git@origin/master#egg=twint
#   Updating ./src/twint clone (to revision origin/master)
#   Running command git fetch -q --tags
#   WARNING: Did not find branch or tag 'origin/master', assuming revision or ref.
#   Running command git reset --hard -q origin/master
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from twint) (3.8.1)
# Requirement already satisfied: aiodns in /usr/local/lib/python3.7/dist-packages (from twint) (3.0.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from twint) (4.6.3)
# Requirement already satisfied: cchardet in /usr/local/lib/python3.7/dist-packages (from twint) (2.1.7)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.7/dist-packages (from twint) (0.6)
# Requirement already satisfied: elasticsearch in /usr/local/lib/python3.7/dist-packages (from twint) (8.3.3)
# Requirement already satisfied: pysocks in /usr/local/lib/python3.7/dist-packages (from twint) (1.7.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from twint) (1.3.5)
# Requirement already satisfied: aiohttp_socks in /usr/local/lib/python3.7/dist-packages (from twint) (0.7.1)
# Requirement already satisfied: schedule in /usr/local/lib/python3.7/dist-packages (from twint) (1.1.0)
# Requirement already satisfied: geopy in /usr/local/lib/python3.7/dist-packages (from twint) (1.17.0)
# Requirement already satisfied: fake-useragent in /usr/local/lib/python3.7/dist-packages (from twint) (0.1.11)
# Requirement already satisfied: googletransx in /usr/local/lib/python3.7/dist-packages (from twint) (2.4.2)
# Requirement already satisfied: pycares>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from aiodns->twint) (4.2.1)
# Requirement already satisfied: cffi>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pycares>=4.0.0->aiodns->twint) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.5.0->pycares>=4.0.0->aiodns->twint) (2.21)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->twint) (1.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from aiohttp->twint) (4.1.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->twint) (2.1.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->twint) (21.4.0)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->twint) (0.13.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->twint) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->twint) (1.7.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->twint) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->twint) (4.0.2)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.7/dist-packages (from yarl<2.0,>=1.0->aiohttp->twint) (2.10)
# Requirement already satisfied: python-socks[asyncio]<3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp_socks->twint) (2.0.3)
# Requirement already satisfied: elastic-transport<9,>=8 in /usr/local/lib/python3.7/dist-packages (from elasticsearch->twint) (8.1.2)
# Requirement already satisfied: urllib3<2,>=1.26.2 in /usr/local/lib/python3.7/dist-packages (from elastic-transport<9,>=8->elasticsearch->twint) (1.26.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from elastic-transport<9,>=8->elasticsearch->twint) (2022.6.15)
# Requirement already satisfied: geographiclib<2,>=1.49 in /usr/local/lib/python3.7/dist-packages (from geopy->twint) (1.52)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from googletransx->twint) (2.28.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->twint) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->twint) (2022.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas->twint) (1.21.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->twint) (1.15.0)
# Installing collected packages: twint
#   Attempting uninstall: twint
#     Found existing installation: twint 2.1.21
#     Can't uninstall 'twint'. No files were found to uninstall.
#   Running setup.py develop for twint
# Successfully installed twint-2.1.21

# %%
# !pip install nest_asyncio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.7/dist-packages (1.5.5)

# %% [markdown]
# **RESTART RUNTIME**

# %%
import twint
import pandas as pd
import nest_asyncio

# %%
nest_asyncio.apply()

# %% [markdown]
# ### 2 -  Declare parameters to acquire tweets/account info

# %%
# provide username
username = 'larrouturou'

# provide keyword or search string
keyword = 'zubair'

# provide the number of most recent tweets you want to scrape
N = 500

# provide the beginning date ('YYYY-MM-DD' format)
since_date = '2011-01-01'

# provide the end date
until_date = '2022-08-01'

# %% [markdown]
# ### 3 - Scrape tweets from a Twitter acccount

# %%
def get_tweets (user_name, num, since_date, until_date):
    print ("======================================")
    print(":: Acquiring tweets of", user_name, "::")
    print ("======================================")

    # Configure
    c = twint.Config()

    c.Username = user_name

    c.Since = since_date
    c.Until = until_date

    c.Limit = num

    #c.Retweets = True

    #c.Lang = 'nl'
    #c.Translate = True 
    #c.TranslateDest = "en"

    c.Store_object =  True
    c.User_full = True
    c.Profile_full = True
    c.Hide_output = True

    c.Pandas = True
    twint.run.Search(c)

    return pd.DataFrame(twint.storage.panda.Tweets_df)

# %%
output  = get_tweets (user_name=username, num=N, since_date=since_date, until_date=until_date)
output.head()
# Out:
# ======================================
# :: Acquiring tweets of larrouturou ::
# ======================================
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
#                     id      conversation_id    created_at  \
# 0  1552978165756215296  1552978165756215296  1.659094e+12
# 1  1548951688555397120  1548948519909728257  1.658134e+12
# 2  1548949157473357834  1548948519909728257  1.658133e+12
# 3  1548948519909728257  1548948519909728257  1.658133e+12
# 4  1548377536404393986  1548377536404393986  1.657997e+12
#
#                   date timezone place  \
# 0  2022-07-29 11:23:42    +0000
# 1  2022-07-18 08:43:55    +0000
# 2  2022-07-18 08:33:51    +0000
# 3  2022-07-18 08:31:19    +0000
# 4  2022-07-16 18:42:26    +0000
#
#                                                tweet language hashtags  \
# 0  Ce qui se passe “équivaut à des incendies sous...       fr       []
# 1  @mbrehin On le fait tous les jours! 💪 @Fresque...       fr       []
# 2  L'étude en question :  https://t.co/itwSxY1BNN...       fr       []
# 3  Projections de chercheurs français en 2017: ce...       fr       []
# 4  L’été dernier, c’était les pluies torrentielle...       fr       []
#
#   cashtags  ...  geo source user_rt_id user_rt  retweet_id  \
# 0       []  ...
# 1       []  ...
# 2       []  ...
# 3       []  ...
# 4       []  ...
#
#                                             reply_to retweet_date translate  \
# 0                                                 []
# 1  [{'screen_name': 'mbrehin', 'name': 'Maxime Br...
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#   trans_src  trans_dest
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 38 columns]

# %% [markdown]
# ### 4 - Scrape the account details of an user

# %%
def get_account_info (user_name, num, since_date, until_date):
    print ("===========================================")
    print(":: Scrapping account info of", user_name, "::")
    print ("===========================================")

    # Configure
    c = twint.Config()

    c.Username = user_name

    c.Since = since_date
    c.Until = until_date

    c.Limit = num

    #c.Lang = 'nl'

    c.Store_object =  True
    c.User_full = True
    c.Profile_full = True
    c.Hide_output = True

    c.Pandas = True
    twint.run.Lookup(c)

    return pd.DataFrame(twint.storage.panda.User_df)

# %%
result  = get_account_info (user_name=username, num=N, since_date=since_date, until_date=until_date)
result.head()
# Out:
# ===========================================
# :: Scrapping account info of larrouturou ::
# ===========================================
#          id                name     username  \
# 0  18578222  Pierre Larrouturou  larrouturou
#
#                                                  bio                      url  \
# 0  Justice sociale & climat - Député européen @No...  https://t.co/EVf5dMr0pA
#
#              join_datetime   join_date     join_time  tweets location  \
# 0  2009-01-03 12:10:04 UTC  2009-01-03  12:10:04 UTC   15051
#
#    following  followers  likes  media  private  verified  \
# 0      53295      56808  78723   1711    False      True
#
#                                               avatar  \
# 0  https://pbs.twimg.com/profile_images/144102932...
#
#                                     background_image
# 0  https://pbs.twimg.com/profile_banners/18578222...

# %% [markdown]
# ### 5 - Scrape tweets using a keyword

# %%
def get_all_tweets (keyword, num, since_date, until_date):
    print ("==============================================")
    print(":: Acquiring tweets with keyword", keyword, "::")
    print ("==============================================")

    # Configure
    c = twint.Config()

    c.Search = keyword


    c.Since = since_date
    c.Until = until_date

    c.Limit = num

    #c.Retweets = True

    #c.Lang = 'nl'
    #c.Translate = True 
    #c.TranslateDest = "en"

    c.Store_object =  True
    c.User_full = True
    c.Profile_full = True
    c.Hide_output = True

    c.Pandas = True
    twint.run.Search(c)

    return pd.DataFrame(twint.storage.panda.Tweets_df)

# %%
result  = get_all_tweets (keyword=keyword, num=N, since_date=since_date, until_date=until_date)
result.head()
# Out:
# ==============================================
# :: Acquiring tweets with keyword zubair ::
# ==============================================
#                     id      conversation_id    created_at  \
# 0  1553893150514499584  1553650620380225537  1.659312e+12
# 1  1553893070977974273  1553796252906663937  1.659312e+12
# 2  1553893046743248896  1553719258189770755  1.659312e+12
# 3  1553892341005529088  1553650620380225537  1.659312e+12
# 4  1553892270952546304  1552693100165926912  1.659312e+12
#
#                   date timezone place  \
# 0  2022-07-31 23:59:31    +0000
# 1  2022-07-31 23:59:12    +0000
# 2  2022-07-31 23:59:06    +0000
# 3  2022-07-31 23:56:18    +0000
# 4  2022-07-31 23:56:01    +0000
#
#                                                tweet language hashtags  \
# 0  @shutup349 @sakshijoshii @zoo_bear What is thi...       en       []
# 1  @MahuaMoitra @zoo_bear @thewire_in Is this tru...       en       []
# 2                             @zoo_bear Dog returned       en       []
# 3  @zoo_bear And you @zoo_bear had restored peace...       en       []
# 4  @YSBayero @zubair_nasr Why so harsh brother?if...       en       []
#
#   cashtags  ...  geo source user_rt_id user_rt  retweet_id  \
# 0       []  ...
# 1       []  ...
# 2       []  ...
# 3       []  ...
# 4       []  ...
#
#                                             reply_to retweet_date translate  \
# 0  [{'screen_name': 'shutup349', 'name': 'Gup Sup...
# 1  [{'screen_name': 'MahuaMoitra', 'name': 'Mahua...
# 2  [{'screen_name': 'zoo_bear', 'name': 'Mohammed...
# 3  [{'screen_name': 'zoo_bear', 'name': 'Mohammed...
# 4  [{'screen_name': 'YSBayero', 'name': 'YSB', 'i...
#
#   trans_src  trans_dest
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 38 columns]
